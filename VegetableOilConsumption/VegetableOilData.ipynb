# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Vegetable Oil Consumption Per Capita

# %%
df = pd.read_excel('VegetableOilConsumptionPerCapita.xlsx')

# %%
#Visualizing Data
df.head()
# Out:
#   Vegetable Oil Consumption Per Capita Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                          Yearly Data      Units       1961       1962
# 1                          Afghanistan         kg     locked     locked
# 2                              Albania         kg     locked     locked
# 3                              Algeria         kg     locked     locked
# 4                               Angola         kg     locked     locked
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0       1963       1964       1965       1966       1967       1968  ...
# 1     locked     locked     locked     locked     locked     locked  ...
# 2     locked     locked     locked     locked     locked     locked  ...
# 3     locked     locked     locked     locked     locked     locked  ...
# 4     locked     locked     locked     locked     locked     locked  ...
#
#   Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# ...

# %%
#Analyzing shape of array (rows, columns)
df.shape
# Out:
# (160, 55)

# %%
#Resetting the labels
df.set_axis([n for n in range(1959, 2015)], axis='columns', inplace=True)

# %%
#Renaming Columns
df.rename(columns={1959 : 'Countries', 1960 : 'Units'}, inplace=True)
df.head()
# Out:
#      Countries  Units    1961    1962    1963    1964    1965    1966    1967  \
# 0  Yearly Data  Units    1961    1962    1963    1964    1965    1966    1967
# 1  Afghanistan     kg  locked  locked  locked  locked  locked  locked  locked
# 2      Albania     kg  locked  locked  locked  locked  locked  locked  locked
# 3      Algeria     kg  locked  locked  locked  locked  locked  locked  locked
# 4       Angola     kg  locked  locked  locked  locked  locked  locked  locked
#
#      1968  ...    2005    2006     2007     2008    2009    2010  2011  \
# 0    1968  ...    2005    2006  2007.00  2008.00  2009.0  2010.0  2011
# 1  locked  ...  locked  locked     3.48     2.39     2.9     3.4   3.2
# 2  locked  ...  locked  locked     7.00     6.30     7.0     5.7   5.4
# 3  locked  ...  locked  locked    13.60    13.70    12.3    13.3  14.9
# 4  locked  ...  locked  locked     9.05     8.63     8.9     8.8   8.8
#
#      2012    2013     2014
# 0    2012    2013   Source
# ...

# %%
#Dropping Source Column
df.drop([2014], axis=1, inplace=True)

# %%
#Dropping yearly Data row
df.drop([0], axis=0, inplace=True)
df.head()
# Out:
#      Countries Units    1961    1962    1963    1964    1965    1966    1967  \
# 1  Afghanistan    kg  locked  locked  locked  locked  locked  locked  locked
# 2      Albania    kg  locked  locked  locked  locked  locked  locked  locked
# 3      Algeria    kg  locked  locked  locked  locked  locked  locked  locked
# 4       Angola    kg  locked  locked  locked  locked  locked  locked  locked
# 5    Argentina    kg  locked  locked  locked  locked  locked  locked  locked
#
#      1968  ...    2004    2005    2006   2007   2008  2009  2010  2011  \
# 1  locked  ...  locked  locked  locked   3.48   2.39   2.9   3.4   3.2
# 2  locked  ...  locked  locked  locked   7.00   6.30   7.0   5.7   5.4
# 3  locked  ...  locked  locked  locked  13.60  13.70  12.3  13.3  14.9
# 4  locked  ...  locked  locked  locked   9.05   8.63   8.9   8.8   8.8
# 5  locked  ...  locked  locked  locked  14.60  14.50  14.4  14.5  14.8
#
#      2012    2013
# 1  locked  locked
# 2  locked  locked
# ...

# %%
#Observing Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 1 to 160
# Data columns (total 55 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Countries  160 non-null    object
#  1   Units      160 non-null    object
#  2   1961       160 non-null    object
#  3   1962       160 non-null    object
#  4   1963       160 non-null    object
#  5   1964       160 non-null    object
#  6   1965       160 non-null    object
#  7   1966       160 non-null    object
#  8   1967       160 non-null    object
#  9   1968       160 non-null    object
#  10  1969       160 non-null    object
#  11  1970       160 non-null    object
#  12  1971       160 non-null    object
#  13  1972       160 non-null    object
#  14  1973       160 non-null    object
#  15  1974       160 non-null    object
#  16  1975       160 non-null    object
#  17  1976       160 non-null    object
#  18  1977       160 non-null    object
# ...

# %%
#Checking There are unique values
df['Units'].unique()
# Out:
# array(['kg'], dtype=object)

# %%
#Checking duplicates
df.duplicated(subset=['Units']).sum()
# Out:
# 159

# %%
#Checking duplicates
df.duplicated(subset=['Countries']).sum()
# Out:
# 0

# %%
df.head()
# Out:
#      Countries Units    1961    1962    1963    1964    1965    1966    1967  \
# 1  Afghanistan    kg  locked  locked  locked  locked  locked  locked  locked
# 2      Albania    kg  locked  locked  locked  locked  locked  locked  locked
# 3      Algeria    kg  locked  locked  locked  locked  locked  locked  locked
# 4       Angola    kg  locked  locked  locked  locked  locked  locked  locked
# 5    Argentina    kg  locked  locked  locked  locked  locked  locked  locked
#
#      1968  ...    2004    2005    2006   2007   2008  2009  2010  2011  \
# 1  locked  ...  locked  locked  locked   3.48   2.39   2.9   3.4   3.2
# 2  locked  ...  locked  locked  locked   7.00   6.30   7.0   5.7   5.4
# 3  locked  ...  locked  locked  locked  13.60  13.70  12.3  13.3  14.9
# 4  locked  ...  locked  locked  locked   9.05   8.63   8.9   8.8   8.8
# 5  locked  ...  locked  locked  locked  14.60  14.50  14.4  14.5  14.8
#
#      2012    2013
# 1  locked  locked
# 2  locked  locked
# ...

# %%
#Cleaning locked values
data = df.drop(df.loc[:, 1961:2006].columns, axis=1).drop(df[[2012, 2013]],axis=1)

# %%
data.tail()
# Out:
#     Countries Units   2007   2008  2009  2010  2011
# 156   Vietnam    kg   2.90   3.30   3.5   3.2   3.2
# 157     Yemen    kg   8.69   8.10   7.0   7.0   7.3
# 158    Zambia    kg   4.44   4.45   4.9   4.6   4.8
# 159  Zimbabwe    kg   8.94  10.49  10.5  10.5    11
# 160     World    kg  11.30  11.20  11.5  11.5  11.7

# %%
#Save Cleaned data to File
data.to_csv('VegetableOilConsumptionPerCapita2007_2011.csv')
