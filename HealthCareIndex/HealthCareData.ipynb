# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.reset_index()
# Out:
#     index   0      Country  Health Care Index  Infrastructure  Professionals  \
# 0       0   1  South Korea              78.72           87.16          14.23
# 1       1   2       Taiwan              77.70           79.05          13.06
# 2       2   3      Denmark              74.11           90.75          30.01
# 3       3   4      Austria              71.32           86.18          20.25
# 4       4   5        Japan              70.73           78.77          21.60
# ..    ...  ..          ...                ...             ...            ...
# 84     84  85   Bangladesh              32.89           70.58          22.84
# 85     85  86   Azerbaijan              32.88           77.80          13.76
# 86     86  87         Iraq              32.55           73.74          14.59
# 87     87  88     Pakistan              32.52           73.36          18.25
# 88     88  89    Venezuela              32.42           71.39          17.16
#
# ...

# %%
df.columns
# Out:
# Index(['0', 'Country', 'Health Care Index', 'Infrastructure', 'Professionals',
#        'Cost', 'Medicine Availability', 'Government Readiness'],
#       dtype='object')

# %%
df.drop(['0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country  Health Care Index  Infrastructure  Professionals   Cost  \
# 0  South Korea              78.72           87.16          14.23  83.59
# 1       Taiwan              77.70           79.05          13.06  78.39
# 2      Denmark              74.11           90.75          30.01  82.59
# 3      Austria              71.32           86.18          20.25  78.99
# 4        Japan              70.73           78.77          21.60  74.88
#
#    Medicine Availability  Government Readiness
# 0                  82.30                 87.89
# 1                  78.99                 65.09
# 2                  92.06                 96.30
# 3                  88.23                 91.80
# 4                  74.18                 93.20

# %%
df.to_csv('formatted')
